# %% [markdown]
# ## Example 3: Rule based logic recognizer

# %% [markdown]
# recognizer : simply an object whose job is to Look at some text and tell me if you found a certain type of entity
#
# how can a recognizer recognize something : ??
# there is not one method but collection of many technichs :
# - method 1: Regex , example : alaa@gmail.com
# - method 2 : list based recognization
# - method 3 : NLM model

# %% [markdown]
# ### step 3 : if non of the 3 methods work ?

# %% [markdown]
# example : a company has a rule : every word that start with EMP- and is followed by exactly 5 digits is an employee id .... unless the next word is "temporary"

# %% [markdown]
# - in this case and in many case like it we will have to write costum rules of our own

# %% [markdown]
# ### step 4: what does "rule based logic" mean ?

# %% [markdown]
# simply u rewrite the logic urself

# %% [markdown]
# ## The Code

# %%
from typing import List 
from presidio_analyzer import AnalyzerEngine, RecognizerResult
from presidio_analyzer.nlp_engine import NlpArtifacts
